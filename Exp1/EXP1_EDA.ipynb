# %% [markdown]
# Downloading Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib
# %matplotlib inline
import seaborn as sns
matplotlib.style.use('seaborn')
import matplotlib.pyplot as plt

# %% [markdown]
# Mounting to google drive to get the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
drive.mount("MyDrive")
os.chdir("MyDrive")
os.chdir("MyDrive")
os.listdir()

# %% [markdown]
# Importing the dataset

# %%
df = pd.read_csv('HappinessData.csv', sep=',', encoding='latin-1')

# %%
df.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
df.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %% [markdown]
# MEANING OF TERMS USED IN THE DATASET
#
# GDP per capita:GDP per capita is a measure of a country's economic output that accounts for its number of people.
#
# Social support:Social support means having friends and other people, including family, to turn to in times of need or crisis to give you a broader focus and positive self-image. Social support enhances quality of life and provides a buffer against adverse life events.
#
# Healthy life expectancy:Healthy Life Expectancy is the average number of years that a newborn can expect to live in "full health"—in other words, not hampered by disabling illnesses or injuries.
#
# Freedom to make life choices:Freedom of choice describes an individual's opportunity and autonomy to perform an action selected from at least two available options, unconstrained by external parties.
#
# Generosity:the quality of being kind and generous.
#
# Perceptions of corruption:The Corruption Perceptions Index (CPI) is an index published annually by Transparency International since 1995 which ranks countries "by their perceived levels of public sector corruption, as determined by expert assessments and opinion surveys.

# %% [markdown]
# Dropping unwanted columns

# %%
# df = df.drop([''], axis = 1)

# %% [markdown]
# Checking for other null value attributes

# %%
df.isna().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %% [markdown]
# Getting rid of null values

# %%
# df[""].fillna("Unknown", inplace = True)

# %% [markdown]
# Printing number of unique data in each of the features

# %%
for col in df:
  space =  ' '*(30-len(col))
  print(col,space,len(df[col].unique()) )
# Out:
# Country name                    149
# Regional indicator              10
# Ladder score                    147
# Standard error of ladder score  65
# upperwhisker                    146
# lowerwhisker                    143
# Logged GDP per capita           148
# Social support                  119
# Healthy life expectancy         135
# Freedom to make life choices    126
# Generosity                      130
# Perceptions of corruption       130
# Ladder score in Dystopia        1
# Explained by: Log GDP per capita  138
# Explained by: Social support    135
# Explained by: Healthy life expectancy  119
# Explained by: Freedom to make life choices  130
# Explained by: Generosity        119
# Explained by: Perceptions of corruption  117
# Dystopia + residual             142

# %% [markdown]
# Highlighting the maximum value of each attribute in the data set

# %%
original=df.copy()
def highlight_max(s):    
    is_max = s == s.max()
    return ['background-color: limegreen' if v else '' for v in is_max]
 
df.style.apply(highlight_max, subset=['Ladder score','Logged GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption'])
# Out:
# <style type="text/css">
# #T_23776_row0_col2, #T_23776_row3_col7, #T_23776_row7_col6, #T_23776_row31_col8, #T_23776_row41_col9, #T_23776_row59_col11, #T_23776_row81_col10, #T_23776_row96_col7 {
#   background-color: limegreen;
# }
# </style>
# <table id="T_23776_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country name</th>
#       <th class="col_heading level0 col1" >Regional indicator</th>
#       <th class="col_heading level0 col2" >Ladder score</th>
#       <th class="col_heading level0 col3" >Standard error of ladder score</th>
#       <th class="col_heading level0 col4" >upperwhisker</th>
#       <th class="col_heading level0 col5" >lowerwhisker</th>
#       <th class="col_heading level0 col6" >Logged GDP per capita</th>
#       <th class="col_heading level0 col7" >Social support</th>
#       <th class="col_heading level0 col8" >Healthy life expectancy</th>
# ...

# %% [markdown]
# Checking the shape of my dataset

# %%
df.shape
# Out:
# (149, 20)

# %% [markdown]
# VISUALIZING THE DATA

# %% [markdown]
# Histplots -
# Regional indicator

# %%
sns.histplot(x='Regional indicator', data=df, )
plt.show()

# %% [markdown]
# Histplots -
# Perceptions of corruption

# %%
sns.histplot(x='Perceptions of corruption', data=df, )
plt.show()

# %% [markdown]
# Histplots -
# Logged GDP per capita

# %%
sns.histplot(x='Logged GDP per capita', data=df, )
plt.show()

# %% [markdown]
# Finding out attributes which are highly correlated to each other through heatmap.

# %%
corrmat = df.corr()
f, ax = plt.subplots()
sns.heatmap(corrmat, square=True)

# %% [markdown]
# Plotting pairwise relationships in the dataset.

# %%
sns.pairplot(df)

# %% [markdown]
# Top 10 countries for each attribute

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,constrained_layout=True,figsize=(12,8))

sns.barplot(x='Logged GDP per capita',y='Regional indicator',data=df.nlargest(10,'Logged GDP per capita'),ax=axes[0,0],palette="Blues_d")

sns.barplot(x='Social support' ,y='Regional indicator',data=df.nlargest(10,'Social support'),ax=axes[0,1],palette="YlGn")

sns.barplot(x='Healthy life expectancy' ,y='Regional indicator',data=df.nlargest(10,'Healthy life expectancy'),ax=axes[1,0],palette='OrRd')

sns.barplot(x='Freedom to make life choices' ,y='Regional indicator',data=df.nlargest(10,'Freedom to make life choices'),ax=axes[1,1],palette='YlOrBr')

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,constrained_layout=True,figsize=(12,8))

sns.barplot(x='Logged GDP per capita',y='Country name',data=df.nlargest(10,'Logged GDP per capita'),ax=axes[0,0],palette="Blues_d")

sns.barplot(x='Social support' ,y='Country name',data=df.nlargest(10,'Social support'),ax=axes[0,1],palette="YlGn")

sns.barplot(x='Healthy life expectancy' ,y='Country name',data=df.nlargest(10,'Healthy life expectancy'),ax=axes[1,0],palette='OrRd')

sns.barplot(x='Freedom to make life choices' ,y='Country name',data=df.nlargest(10,'Freedom to make life choices'),ax=axes[1,1],palette='YlOrBr')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2,constrained_layout=True,figsize=(10,4))

sns.barplot(x='Generosity' ,y='Regional indicator',data=df.nlargest(10,'Generosity'),ax=axes[0],palette='Spectral')
sns.barplot(x='Perceptions of corruption' ,y='Regional indicator',data=df.nlargest(10,'Perceptions of corruption'),ax=axes[1],palette='RdYlGn')

# %% [markdown]
# Now I want to give a category to each country as High,Mid and Low according to their happiness scores.Thus we have to find out the bound in which these categories shall lie in.

# %%
print('max:',df['Ladder score'].max())
print('min:',df['Ladder score'].min())
add=df['Ladder score'].max()-df['Ladder score'].min()
grp=round(add/3,3)
print('range difference:',(grp))
# Out:
# max: 7.842
# min: 2.523
# range difference: 1.773

# %%
low=df['Ladder score'].min()+grp
mid=low+grp

print('upper bound of Low grp',low)
print('upper bound of Mid grp',mid)
print('upper bound of High grp','max:',df['Ladder score'].max())
# Out:
# upper bound of Low grp 4.296
# upper bound of Mid grp 6.069
# upper bound of High grp max: 7.842

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %% [markdown]
# Finally adding a new column Category to the dataset and distributing the levels High,Low,Mid.

# %%
cat=[]
for i in df['Ladder score']:
    if(i>0 and i<low):
        cat.append('Low')
        
        
    elif(i>low and i<mid):
         cat.append('Mid')
    else:
         cat.append('High')

df['Category']=cat

# %% [markdown]
# Styling the dataset as a green zone and red zone .If the country belongs to the High category then it is under the green zone and if it is under the Mid or Low category it is goinf to be the red zone

# %%
color = (df.Category == 'High' ).map({True: 'background-color: limegreen',False:'background-color: red'})
df.style.apply(lambda s: color)
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# See a countries position on the list and also checkout some other countries where people from India usually settle

# %%
df.loc[df['Regional indicator']=='Middle East and North Africa']
# Out:
#                 Country name            Regional indicator  Ladder score  \
# 11                    Israel  Middle East and North Africa         7.157
# 21                   Bahrain  Middle East and North Africa         6.647
# 24      United Arab Emirates  Middle East and North Africa         6.561
# 25              Saudi Arabia  Middle East and North Africa         6.494
# 46                    Kuwait  Middle East and North Africa         6.106
# 79                     Libya  Middle East and North Africa         5.410
# 103                   Turkey  Middle East and North Africa         4.948
# 105                  Morocco  Middle East and North Africa         4.918
# 108                  Algeria  Middle East and North Africa         4.887
# 110                     Iraq  Middle East and North Africa         4.854
# 117                     Iran  Middle East and North Africa         4.721
# 121                  Tunisia  Middle East and North Africa         4.596
# ...

# %%
df.loc[df['Regional indicator']=='Western Europe']
# Out:
#       Country name Regional indicator  Ladder score  \
# 0          Finland     Western Europe         7.842
# 1          Denmark     Western Europe         7.620
# 2      Switzerland     Western Europe         7.571
# 3          Iceland     Western Europe         7.554
# 4      Netherlands     Western Europe         7.464
# 5           Norway     Western Europe         7.392
# 6           Sweden     Western Europe         7.363
# 7       Luxembourg     Western Europe         7.324
# 9          Austria     Western Europe         7.268
# 12         Germany     Western Europe         7.155
# 14         Ireland     Western Europe         7.085
# 16  United Kingdom     Western Europe         7.064
# 19         Belgium     Western Europe         6.834
# 20          France     Western Europe         6.690
# 22           Malta     Western Europe         6.602
# 26           Spain     Western Europe         6.491
# 27           Italy     Western Europe         6.483
# ...

# %%
df.loc[df['Regional indicator']=='North America and ANZ']
# Out:
#      Country name     Regional indicator  Ladder score  \
# 8     New Zealand  North America and ANZ         7.277
# 10      Australia  North America and ANZ         7.183
# 13         Canada  North America and ANZ         7.103
# 18  United States  North America and ANZ         6.951
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 8                            0.040         7.355         7.198
# 10                           0.041         7.265         7.102
# 13                           0.042         7.185         7.021
# 18                           0.049         7.047         6.856
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 8                  10.643           0.948                     73.4
# 10                 10.796           0.940                     73.9
# 13                 10.776           0.926                     73.8
# 18                 11.023           0.920                     68.2
#
# ...

# %%
df.loc[df['Regional indicator']=='Latin America and Caribbean']
# Out:
#            Country name           Regional indicator  Ladder score  \
# 15           Costa Rica  Latin America and Caribbean         7.069
# 29            Guatemala  Latin America and Caribbean         6.435
# 30              Uruguay  Latin America and Caribbean         6.431
# 34               Brazil  Latin America and Caribbean         6.330
# 35               Mexico  Latin America and Caribbean         6.317
# 36              Jamaica  Latin America and Caribbean         6.309
# 40               Panama  Latin America and Caribbean         6.180
# 42                Chile  Latin America and Caribbean         6.172
# 48          El Salvador  Latin America and Caribbean         6.061
# 51             Colombia  Latin America and Caribbean         6.012
# 54            Nicaragua  Latin America and Caribbean         5.972
# 56            Argentina  Latin America and Caribbean         5.929
# 58             Honduras  Latin America and Caribbean         5.919
# ...

# %%
df.loc[df['Regional indicator']=='Central and Eastern Europe']
# Out:
#               Country name          Regional indicator  Ladder score  \
# 17          Czech Republic  Central and Eastern Europe         6.965
# 28                Slovenia  Central and Eastern Europe         6.461
# 32                  Kosovo  Central and Eastern Europe         6.372
# 33                Slovakia  Central and Eastern Europe         6.331
# 37               Lithuania  Central and Eastern Europe         6.255
# 39                 Estonia  Central and Eastern Europe         6.189
# 43                  Poland  Central and Eastern Europe         6.166
# 45                 Romania  Central and Eastern Europe         6.140
# 47                  Serbia  Central and Eastern Europe         6.078
# 50                  Latvia  Central and Eastern Europe         6.032
# 52                 Hungary  Central and Eastern Europe         5.992
# 59                 Croatia  Central and Eastern Europe         5.882
# 63  Bosnia and Herzegovina  Central and Eastern Europe         5.813
# ...

# %% [markdown]
# All of them belong to the HIGH category and apparently Central and Eastern Europe is pretty high upand has a great happiness score.
# :

# %%
d= df[(df['Regional indicator'].isin(['Central and Eastern Europe','Latin America and Caribbean','North America and ANZ', 'Western Europe']))]
d
# Out:
#         Country name           Regional indicator  Ladder score  \
# 0            Finland               Western Europe         7.842
# 1            Denmark               Western Europe         7.620
# 2        Switzerland               Western Europe         7.571
# 3            Iceland               Western Europe         7.554
# 4        Netherlands               Western Europe         7.464
# ..               ...                          ...           ...
# 87          Bulgaria   Central and Eastern Europe         5.266
# 92           Albania   Central and Eastern Europe         5.117
# 93   North Macedonia   Central and Eastern Europe         5.101
# 106        Venezuela  Latin America and Caribbean         4.892
# 142            Haiti  Latin America and Caribbean         3.615
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# ...

# %% [markdown]
# Social Support vs GDP per capita vs Healthy life expectancy

# %%
ax = d.plot(y="Social support", x="Regional indicator", kind="bar",color='C3')
d.plot(y="Logged GDP per capita", x="Regional indicator", kind="bar", ax=ax, color="C1")
d.plot(y="Healthy life expectancy", x="Regional indicator", kind="bar", ax=ax, color="C2")

plt.show()

# %% [markdown]
# Freedom to make life choices vs Generosity vs Corruption

# %%
ax = d.plot(y="Freedom to make life choices", x="Regional indicator", kind="bar",color='C3')
d.plot(y="Generosity", x="Regional indicator", kind="bar", ax=ax, color="C1",)
d.plot(y="Perceptions of corruption", x="Regional indicator", kind="bar", ax=ax, color="C2",)

plt.show()

# %% [markdown]
# Geographic Visualization of Happiness Score

# %%
import plotly.graph_objs as go
from plotly.offline import iplot

data = dict(type = 'choropleth', 
           locations = df['Country name'],
           locationmode = 'country names',
           colorscale='RdYlGn',
           z = df['Ladder score'], 
           text = df['Country name'],
           colorbar = {'title':'Happiness Score'})

layout = dict(title = 'Geographical Visualization of Happiness Score', 
              geo = dict(showframe = True, projection = {'type': 'azimuthal equal area'}))

choromap3 = go.Figure(data = [data], layout=layout)
iplot(choromap3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Objective
#
# To perform Exploratory Data Analysis such as number of data samples, number of features, number of classes, number of data samples per class, removing missing values, conversion to numbers, using seaborn library to plot different graphs.

# %% [markdown]
# Conclusion

# %% [markdown]
# In this document, we perform a detailed data analysis on the World Happiness Report with its relation to the socio-economic North-South Divide. In order to do so, we perform some extensive data cleaning and analysis before querying on the World Happiness Report. Our results based on Hypothesis Testing determines the happiness of the Global North is greater than that of the Global South. Furthermore, our queries show that the mean happiness score for the Global North significantly outweighing that of the South. Likewise, the 10 'Happiest' nations all belong to the Global North whereas the 10 'least happy' nations belong to the Global South.
